# %% [markdown]
# # JC3503 Assignment - Student Records
#
# ---
#
# Student Name:
#
# Student Email:
#
# Student ID:
#
# ---
#
# Additional information about the dataset: https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success

# %%
# Add any pre-requisites or libraries here
import pandas as pd
import seaborn as sns
import sklearn as sk
from sklearn import linear_model


# Import the data
df = pd.read_csv("student_records.csv", low_memory=False)

# %% [markdown]
# Start with a glance at the data

# %%
df.head(5)
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# # 1.  Data cleaning
# ## 1.1 Find empty data
# We want to clean the data, fill in the empty data, and find the wrong data.
# Let's first check to see if we have any empty data.

# %%
df.isna().any()
# Out:
# Marital status                                    False
# Application mode                                  False
# Application order                                 False
# Course                                            False
# Daytime/evening attendance\t                      False
# Previous qualification                            False
# Previous qualification (grade)                    False
# Nacionality                                       False
# Mother's qualification                            False
# Father's qualification                            False
# Mother's occupation                               False
# Father's occupation                               False
# Admission grade                                   False
# Displaced                                         False
# Educational special needs                         False
# Debtor                                            False
# Tuition fees up to date                           False
# ...

# %% [markdown]
# We can see from the returned data that there is no empty data in the dataset.
# ## 1.2 Find extreme or erroneous data
# Let's use describe method to get an overview of the data.

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %% [markdown]
# From the above data we find that all the data fall within the valid range and no additional operations on the data are needed.
# # 2. Data analysis
# ## 2.1 Distribution of discrete data
# Let's start by looking at the distribution of discrete data, such as student marriages, course choices, and so on.

# %%
sns.displot(data=df, x="Marital status")
